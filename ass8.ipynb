# %%
# Q.1

def minimumDeleteSum(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0] * (n+1) for _ in range(m+1)]

    for i in range(1, m+1):
        dp[i][0] = dp[i-1][0] + ord(s1[i-1])

    for j in range(1, n+1):
        dp[0][j] = dp[0][j-1] + ord(s2[j-1])

    for i in range(1, m+1):
        for j in range(1, n+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1]
            else:
                dp[i][j] = min(dp[i-1][j] + ord(s1[i-1]), dp[i][j-1] + ord(s2[j-1]))

    return dp[m][n]

# %%
# Q.2

def isValid(s):
    stack = []

    for ch in s:
        if ch == '(' or ch == '*':
            stack.append(ch)
        elif ch == ')':
            if stack:
                stack.pop()
            else:
                return False

    while stack:
        if stack.pop() != '(':
            return False

    return True

# %%
# Q.3

def minSteps(word1, word2):
    m, n = len(word1), len(word2)
    dp = [[0] * (n+1) for _ in range(m+1)]

    for i in range(1, m+1):
        dp[i][0] = i

    for j in range(1, n+1):
        dp[0][j] = j

    for i in range(1, m+1):
        for j in range(1, n+1):
            if word1[i-1] == word2[j-1]:
                dp[i][j] = dp[i-1][j-1]
            else:
                dp[i][j] = min(dp[i-1][j], dp[i][j-1]) + 1

    return dp[m][n]

# %%
# Q.4

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def buildTree(sub_str):
    if not sub_str:
        return None

    if '(' not in sub_str:
        root_val = int(sub_str)
        return TreeNode(root_val)

    root_end = sub_str.index('(')
    root_val = int(sub_str[:root_end])
    root = TreeNode(root_val)

    left_start = root_end
    left_end = findMatchingClosingParenthesis(sub_str, left_start)
    root.left = buildTree(sub_str[left_start + 1:left_end])

    if left_end < len(sub_str) - 1:
        right_start = left_end + 1
        right_end = findMatchingClosingParenthesis(sub_str, right_start)
        root.right = buildTree(sub_str[right_start + 1:right_end])

    return root

def findMatchingClosingParenthesis(sub_str, start):
    count = 0
    for i in range(start, len(sub_str)):
        if sub_str[i] == '(':
            count += 1
        elif sub_str[i] == ')':
            count -= 1
            if count == 0:
                return i
    return -1

def treeToString(root):
    if not root:
        return ''

    if not root.left and not root.right:
        return str(root.val)

    left_str = treeToString(root.left)
    right_str = treeToString(root.right)

    result = str(root.val)
    if left_str:
        result += '(' + left_str + ')'
    if right_str:
        result += '(' + right_str + ')'

    return result

def constructTreeFromString(s):
    root = buildTree(s)
    return treeToString(root)

# %%
# Q.5

def compress(chars):
    readPtr = 0
    writePtr = 0
    count = 1

    for readPtr in range(1, len(chars) + 1):
        if readPtr < len(chars) and chars[readPtr] == chars[readPtr - 1]:
            count += 1
        else:
            chars[writePtr] = chars[readPtr - 1]
            writePtr += 1

            if count > 1:
                countDigits = len(str(count))
                for digit in str(count):
                    chars[writePtr] = digit
                    writePtr += 1

            count = 1

    return writePtr

# %%
# Q.6

from collections import defaultdict

def findAnagrams(s, p):
    pFreq = defaultdict(int)
    windowFreq = defaultdict(int)
    result = []
    pLen = len(p)
    sLen = len(s)

    for char in p:
        pFreq[char] += 1

    left = 0
    right = 0

    while right < sLen:
        windowFreq[s[right]] += 1

        if right - left + 1 == pLen:
            if windowFreq == pFreq:
                result.append(left)

            windowFreq[s[left]] -= 1
            if windowFreq[s[left]] == 0:
                del windowFreq[s[left]]

            left += 1

        right += 1

    return result

# %%
# Q.7

def decodeString(s):
    stack = []

    for ch in s:
        if ch.isdigit():
            stack.append(int(ch))
        elif ch == '[':
            stack.append('')
        elif ch == ']':
            count = stack.pop()
            encoded_str = stack.pop()
            decoded_str = encoded_str * count

            if stack and isinstance(stack[-1], str):
                prev_decoded_str = stack.pop()
                decoded_str = prev_decoded_str + decoded_str

            stack.append(decoded_str)
        else:
            if stack and isinstance(stack[-1], str):
                stack[-1] += ch
            else:
                stack.append(ch)

    return stack[0]

# %%
# Q.8

def buddyStrings(s, goal):
    if len(s) != len(goal):
        return False

    diff_indices = []
    diff_chars = []

    for i in range(len(s)):
        if s[i] != goal[i]:
            diff_indices.append(i)
            diff_chars.append(s[i])

    if len(diff_indices) != 2:
        return False

    i, j = diff_indices
    if s[i] == goal[j] and s[j] == goal[i]:
        return True

    return False
